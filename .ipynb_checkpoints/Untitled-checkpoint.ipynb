# %%
import pandas as pd
import numpy as np
import json
import folium
import math
import src.helper_functions1 as hf
import pyspark as ps# for the pyspark suite



spark = ps.sql.SparkSession.builder \
            .master("local[4]") \
            .appName("case study") \
            .getOrCreate()

sc = spark.sparkContext

# %%
data = pd.read_csv('data/shootings.csv')
data.head()
# Out:
#                                          case            location     date  \
# 0               Odessa-Midland shooting spree          Odessa, TX  8/31/19
# 1      Dayton entertainment district shooting          Dayton, OH   8/4/19
# 2               El Paso Walmart mass shooting         El Paso, TX   8/3/19
# 3             Gilroy garlic festival shooting          Gilroy, CA  7/28/19
# 4  Virginia Beach municipal building shooting  Virginia Beach, VA  5/31/19
#
#                                              summary  fatalities  injured  \
# 0  Seth A. Ator, 36, fired at police officers who...           7       22
# 1  Connor Betts, 24, died during the attack, foll...           9       27
# 2  Patrick Crusius, 21, who was apprehended by po...          22       26
# 3  Santino William LeGan, 19, fired indiscriminat...           3       12
# 4  DeWayne Craddock, 40, a municipal city worker ...          12        4
#
#    total_victims location.1  age_of_shooter prior_signs_mental_health_issues  \
# 0             29      Other              36                                -
# 1             36      Other              24                                -
# 2             48  Workplace              21                                -
# 3             15      Other              19                              TBD
# 4             16  Workplace              40                              TBD
#
#    ...                                     weapon_details   race gender  \
# 0  ...                                                  -  White      M
# 1  ...  AR-15-style rifle, with a 100-round capacity a...  White      M
# 2  ...                 AK-47-style rifle, per authorities  White      M
# 3  ...                 AK-47-style rifle, per authorities      -      M
# 4  ...                               .45-caliber handguns  Black      M
#
#                                              sources mental_health_sources  \
# 0  https://www.washingtonpost.com/politics/5-kill...                     -
# 1  https://www.nytimes.com/2019/08/04/us/dayton-o...                     -
# 2  https://www.washingtonpost.com/nation/2019/08/...                     -
# 3  https://www.cbsnews.com/live-news/garlic-festi...                     -
# 4  https://www.washingtonpost.com/local/public-sa...                     -
#
#   sources_additional_age   latitude   longitude   type  year
# 0                      -  31.925974 -102.279600  Spree  2019
# 1                      -  39.757312  -84.184947   Mass  2019
# 2                      -  31.771068 -106.375655   Mass  2019
# 3                      -  36.997191 -121.584819   Mass  2019
# 4                      -  36.754420  -76.060378   Mass  2019
#
# [5 rows x 24 columns]

# %%
hf.site_mapper(data, 'fatalities', 'summary', 30)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def read_json(json_file):
    with open(json_file, 'r') as myfile:
        data=myfile.read()
    arr = json.loads(data)
    return arr

# %%
gun_laws = read_json('json/state_gun_laws.json')

# %%
gun_laws_df = pd.read_json('json/state_gun_laws.json').transpose()

# %%
row = {'Long Guns': 1.0, 'Handguns': 1.0}
row['Long Guns'] + row['Handguns']

def parse_row(row):
    if row['Long Guns'] + row['Handguns'] == 0:
        return 0
    else:
        return 1

# %%
assault_weapon_laws = gun_laws_df['Assault weapon law?']
assault_weapon_laws.apply(parse_row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-2595787aa99f> in <module>
#       1 assault_weapon_laws = gun_laws_df['Assault weapon law?']
# ----> 2 assault_weapon_laws.apply(parse_row)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4036             else:
#    4037                 values = self.astype(object).values
# -> 4038                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4039
#    4040         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-62-362eda4ad1b1> in parse_row(row)
#       3
#       4 def parse_row(row):
# ----> 5     if math.isnan(row):
#       6         return 0
#       7     else:
#
# TypeError: must be real number, not dict

# %%
url = 'https://raw.githubusercontent.com/transposevisualization/folium/master/examples/data'
state_geo = f'{url}/us-states.json'
state_unemployment = f'{url}/US_Unemployment_Oct2012.csv'
state_data = pd.read_csv(state_unemployment)

m = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=state_data,
    columns=['State', 'Unemployment'],
    key_on='feature.id',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Unemployment Rate (%)'
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
state_data
# Out:
#    State  Unemployment
# 0     AL           7.1
# 1     AK           6.8
# 2     AZ           8.1
# 3     AR           7.2
# 4     CA          10.1
# 5     CO           7.7
# 6     CT           8.4
# 7     DE           7.1
# 8     FL           8.2
# 9     GA           8.8
# 10    HI           5.4
# 11    ID           6.6
# 12    IL           8.8
# 13    IN           8.4
# 14    IA           5.1
# 15    KS           5.6
# 16    KY           8.1
# 17    LA           5.9
# 18    ME           7.2
# 19    MD           6.8
# 20    MA           6.7
# 21    MI           9.1
# 22    MN           5.6
# 23    MS           9.1
# 24    MO           6.7
# 25    MT           5.8
# 26    NE           3.9
# 27    NV          10.3
# 28    NH           5.7
# 29    NJ           9.6
# 30    NM           6.8
# 31    NY           8.4
# 32    NC           9.4
# 33    ND           3.2
# 34    OH           6.9
# 35    OK           5.2
# 36    OR           8.5
# 37    PA           8.0
# 38    RI          10.1
# 39    SC           8.8
# 40    SD           4.4
# 41    TN           7.8
# 42    TX           6.4
# 43    UT           5.5
# 44    VT           5.0
# 45    VA           5.8
# 46    WA           7.8
# 47    WV           7.5
# 48    WI           6.8
# 49    WY           5.1
